# %%
# Dependencies and Setup
import cProfile as cPr
import gc
from math import radians, sin, cos, sqrt, atan2
from requests import Session
import time
import os

import geopandas as gpd
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from ratelimiter import RateLimiter as RL
from scipy.stats import linregress

from requests_futures.sessions import FuturesSession 

from API.api_key import api_key as ak

# Incorporated citipy to determine city based on latitude and longitude
from citipy.citipy import nearest_city as nc, WORLD_CITIES_DICT as WCD

# Range of latitudes and longitudes 
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
#generates n random coordinate pairs as (latitude,longitude)
def random_coords(n):
    lat = np.random.uniform(lat_range[0], lat_range[1],n)
    lng = np.random.uniform(lng_range[0], lng_range[1],n)
    return zip(lat,lng)

# %%
def city_builder(n):
    allcities = []
    while len(allcities)<n:
        coordcity = {t: nc(*t).city_name for t in random_coords(n)}
        ashortlist = [coordcity[x] for x in coordcity]
        cities = allcities + ashortlist
        allcities = list(set(cities))
    finalcities = np.random.choice(allcities, n,replace=False)
    return finalcities

def city_plotter(cities):
    dic = {v.city_name: k for k,v in WCD.items()}
    gencoordy = []
    gencoordx = []
    for city in cities:
        gencoordy.append(dic[city][0])
        gencoordx.append(dic[city][1])

    fig, ax = plt.subplots(1,1,figsize=(10,12))
    countries = gpd.read_file(gpd.datasets.get_path("naturalearth_lowres"))
    countries.plot(color="grey",ax=ax)
    ax.plot(gencoordx,gencoordy,'bo',ms=5,alpha=.8)
    ax.grid(b=True, alpha=0.6)
    plt.savefig('outputs/worldmap.png')
    plt.close('all')
    return

# %%
def url_builder(cities,key):
    begin_url, api_url = f'http://api.openweathermap.org/data/2.5/weather?q=', f'&appid={key}&units=imperial'
    curl = lambda c: f"{begin_url}{c}{api_url}"
    urls = (curl(c) for c in cities)
    return urls

# %%
def url_split(url):
    url_split1 = url.split('=')
    url_split2 = url_split1[1].split('&')
    city = url_split2[0]
    return city

def call(s,u,counter):
    WeatherData = dict.fromkeys(['City','Country','Date','Latitude','Longitude','Max Temperature (F)','Humidity','Cloudiness','Wind Speed'])
    getcity = url_split
    city = getcity(u)
    try:
        res = s.get(u)
        res.raise_for_status()
        jres = res.json()
        WeatherData['City']            = jres['name']
        WeatherData['Country']         = jres['sys']['country']
        WeatherData['Date']            = jres['dt']
        WeatherData['Latitude']        = jres['coord']['lat']
        WeatherData['Longitude']       = jres['coord']['lon']
        WeatherData['Max Temperature (F)'] = jres['main']['temp_max']
        WeatherData['Humidity']        = jres['main']['humidity']
        WeatherData['Cloudiness']      = jres['clouds']['all']
        WeatherData['Wind Speed']      = jres['wind']['speed']
        print(f"===Record {counter}: {city.capitalize()} | <Status: {res.status_code}>===")
        with open('outputs/requestslog.txt' ,'a') as file:
            file.write(f"-Record {counter}: {city.capitalize()} | <Status: {res.status_code}>-\n")
        return WeatherData

    except:
        print(f'===<Status: {s.get(u).status_code}> | Request for city "{city.capitalize()}" was unsuccessful. Skipping...===')
        with open('outputs/requestslog.txt' ,'a') as file:
            file.write(f'<Status: {s.get.status_code}> | Request for city "{city.capitalize()}" was unsuccessful. Skipping...\n')
        return {city.capitalize(): 'Request Unsuccessful'}

# %%
def all_calls(urls):
    sesh = Session()
    counter = 1
    CityWeather = []
    print('*******************************')
    print('Commence Data Retrievals')
    print('*******************************')
    for u in urls:
        res = call(sesh,u,counter)
        if [*res.values()][0] == 'Request Unsuccessful':
            pass
        else:
            CityWeather.append(res)
            counter += 1
    print('*******************************')
    print('Incredibly Long List Finally Complete')
    print('*******************************')
    return CityWeather

def tocsv(d):
    df = pd.DataFrame(d)
    path='outputs/worldweather.csv'
    df.to_csv(path)
    print('Data exported to csv file.')
    return

# %% [markdown]
# # To request every response:
# ## Choose how many requests to make (n)
# ## Call 'city_writer(n)' to generate n random cities and plot their coordinates with a map of the world underneith
# ## Call 'url_builder(cities,key) with 'ak' as key and the cities returned by 'city_writer'
# ## Call 'all_calls(urls)' using the generator returned by 'url_builder'
# ## Finally, call 'tocsv(d)' using the dictionary returned by 'all_calls(urls)'
# ## You should be left with a print log of all the calls and a csv contaning all of the response data

# %%
@RL(max_calls=60,period=60)
def finale(n):
    try:
        builder = city_builder
        cities = builder(n)
        plot = city_plotter
        plot(cities)
        urls = url_builder
        calls = all_calls
        tocsv(calls(urls(cities,ak)))
    except:
        if os.path.exists("outputs/requestslog.txt"):
            os.remove("outputs/requestslog.txt")
        else:
            pass
        if os.path.exists("outputs/worldmap.png"):
            os.remove("outputs/worldmap.png")
        else:
            pass
    return

# %%
finale(1500)
# Out:
# *******************************
# Commence Data Retrievals
# *******************************
# ===Record 1: Loa janan | <Status 200>===
# ===Record 2: Sakakah | <Status 200>===
# ===Record 3: Usakos | <Status 200>===
# ===Record 4: Rundu | <Status 200>===
# ===Record 5: Kjopsvik | <Status 200>===
# ===<Status: 404> | Request for city "Galiwinku" was unsuccessful. Skipping...===
# ===Record 6: Airai | <Status 200>===
# ===Record 7: Astoria | <Status 200>===
# ===Record 8: Mashhad | <Status 200>===
# ===Record 9: Puerto ayora | <Status 200>===
# ===Record 10: Narsaq | <Status 200>===
# ===Record 11: Itarema | <Status 200>===
# ===Record 12: Sembakung | <Status 200>===
# ===Record 13: Suez | <Status 200>===
# ===Record 14: Garissa | <Status 200>===
# ===Record 15: Saint-jovite | <Status 200>===
# ===Record 16: Carora | <Status 200>===
# ===<Status: 404> | Request for city "Azimur" was unsuccessful. Skipping...===
# ===Record 17: Kyren | <Status 200>===
# ===Record 18: Isiolo | <Status 200>===
# ===Record 19: Vila velha | <Status 200>===
# ===Record 20: Newport | <Status 200>===
# ===Record 21: Saint-joseph | <Status 200>===
# ===Record 22: Karpathos | <Status 200>===
# ===Record 23: Mbanza-ngungu | <Status 200>===
# ===Record 24: Ylivieska | <Status 200>===
# ===Record 25: Cruzeiro do sul | <Status 200>===
# ===<Status: 404> | Request for city "Ijaki" was unsuccessful. Skipping...===
# ===Record 26: Rayong | <Status 200>===
# ===Record 27: Volksrust | <Status 200>===
# ===Record 28: Naze | <Status 200>===
# ===Record 29: Bima | <Status 200>===
# ===Record 30: Yuxia | <Status 200>===
# ===Record 31: Marshall | <Status 200>===
# ===Record 32: Ixtapa | <Status 200>===
# ===<Status: 404> | Request for city "Marcona" was unsuccessful. Skipping...===
# ===Record 95: Sapa | <Status 200>===
# ===Record 96: Nanortalik | <Status 200>===
# ===Record 97: Melita | <Status 200>===
# ===Record 98: Sergeyevka | <Status 200>===
# ===Record 99: Yuzhno-kurilsk | <Status 200>===
# ===<Status: 404> | Request for city "Samalaeulu" was unsuccessful. Skipping...===
# ===Record 100: Chervone | <Status 200>===
# ===<Status: 404> | Request for city "Halalo" was unsuccessful. Skipping...===
# ===Record 101: Zonguldak | <Status 200>===
# ===Record 102: Pimenta bueno | <Status 200>===
# ===Record 103: Kocevje | <Status 200>===
# ===Record 104: Ruidoso | <Status 200>===
# ===Record 105: Semey | <Status 200>===
# ===Record 106: Strezhevoy | <Status 200>===
# ===Record 107: Non sung | <Status 200>===
# ===Record 108: Hobart | <Status 200>===
# ===Record 109: Harrismith | <Status 200>===
# ===Record 110: Laukaa | <Status 200>===
# ===Record 111: Spoleto | <Status 200>===
# ===Record 112: Joshimath | <Status 200>===
# ===Record 113: Olinda | <Status 200>===
# ===Record 114: Kysyl-syr | <Status 200>===
# ===Record 115: Cetraro | <Status 200>===
# ===Record 116: Albany | <Status 200>===
# ===Record 117: Ligayan | <Status 200>===
# ===Record 118: Mumford | <Status 200>===
# ===Record 119: Hauterive | <Status 200>===
# ===Record 120: Half moon bay | <Status 200>===
# ===Record 121: Liverpool | <Status 200>===
# ===Record 122: Ahipara | <Status 200>===
# ===Record 123: Machiques | <Status 200>===
# ===Record 124: Hit | <Status 200>===
# ===Record 125: Staraya russa | <Status 200>===
# ===Record 126: Zhigalovo | <Status 200>===
# ===Record 127: Burgeo | <Status 200>===
# ===Record 128: Sumbe | <Status 200>===
# ===Record 129: Kiboga | <Status 200>===
# ===Record 130: Presidente franco | <Status 200>===
# ===Record 131: Mantua | <Status 200>===
# ===Record 132: Merke | <Status 200>===
# ===Record 133: Estacion coahuila | <Status 200>===
# ===Record 134: Miyako | <Status 200>===
# ===Record 135: Georgiyevka | <Status 200>===
# ===Record 136: Solok | <Status 200>===
# ===Record 137: Imeni stepana razina | <Status 200>===
# ===Record 138: Lithgow | <Status 200>===
# ===Record 139: Kalcheva | <Status 200>===
# ===Record 140: Balkanabat | <Status 200>===
# ===<Status: 404> | Request for city "Samusu" was unsuccessful. Skipping...===
# ===Record 141: Miri | <Status 200>===
# ===Record 142: Pyay | <Status 200>===
# ===Record 143: Jiwani | <Status 200>===
# ===Record 144: Gigmoto | <Status 200>===
# ===<Status: 404> | Request for city "Rungata" was unsuccessful. Skipping...===
# ===Record 145: Roald | <Status 200>===
# ===Record 146: Tucuma | <Status 200>===
# ===Record 147: Cabo san lucas | <Status 200>===
# ===Record 148: Manaure | <Status 200>===
# ===Record 149: Marinette | <Status 200>===
# ===Record 150: Peniche | <Status 200>===
# ===Record 151: General salgado | <Status 200>===
# ===Record 152: Sangar | <Status 200>===
# ===Record 153: Fort-shevchenko | <Status 200>===
# ===Record 154: Parfenyevo | <Status 200>===
# ===Record 155: Talcahuano | <Status 200>===
# ===Record 156: Ganjam | <Status 200>===
# ===<Status: 404> | Request for city "Uwayl" was unsuccessful. Skipping...===
# ===Record 157: Gizo | <Status 200>===
# ===Record 158: Cozumel | <Status 200>===
# ===Record 159: Uyuni | <Status 200>===
# ===Record 160: Butaritari | <Status 200>===
# ===Record 161: Dargaville | <Status 200>===
# ===Record 162: Kangaatsiaq | <Status 200>===
# ===Record 163: Natitingou | <Status 200>===
# ===Record 164: Tumut | <Status 200>===
# ===<Status: 404> | Request for city "Tarudant" was unsuccessful. Skipping...===
# ===Record 165: Otane | <Status 200>===
# ===Record 166: Mitsamiouli | <Status 200>===
# ===<Status: 404> | Request for city "Huetamo" was unsuccessful. Skipping...===
# ===Record 167: Pionerskiy | <Status 200>===
# ===Record 168: Milkovo | <Status 200>===
# ===Record 169: Tres arroyos | <Status 200>===
# ===Record 170: Ketchikan | <Status 200>===
# ===Record 171: Tshane | <Status 200>===
# ===<Status: 404> | Request for city "Aflu" was unsuccessful. Skipping...===
# ===Record 172: Abashiri | <Status 200>===
# ===Record 173: Tanah merah | <Status 200>===
# ===Record 174: Honningsvag | <Status 200>===
# ===Record 175: Anekal | <Status 200>===
# ===Record 176: Kulhudhuffushi | <Status 200>===
# ===Record 177: Nuuk | <Status 200>===
# ===Record 178: Barraute | <Status 200>===
# ===Record 179: Uyemskiy | <Status 200>===
# ===Record 180: Iskateley | <Status 200>===
# ===Record 181: Colares | <Status 200>===
# ===Record 182: Ambatofinandrahana | <Status 200>===
# ===Record 183: Mayor pablo lagerenza | <Status 200>===
# ===Record 184: Arman | <Status 200>===
# ===Record 185: Marzuq | <Status 200>===
# ===Record 186: Minas | <Status 200>===
# ===Record 187: Tuktoyaktuk | <Status 200>===
# ===<Status: 404> | Request for city "Palabuhanratu" was unsuccessful. Skipping...===
# ===Record 188: Sovetskaya gavan | <Status 200>===
# ===Record 189: Sao joao de pirabas | <Status 200>===
# ===Record 190: Kitob | <Status 200>===
# ===Record 191: Lamar | <Status 200>===
# ===Record 192: Toumodi | <Status 200>===
# ===Record 193: Torphins | <Status 200>===
# ===<Status: 404> | Request for city "Sorvag" was unsuccessful. Skipping...===
# ===Record 194: Mana | <Status 200>===
# ===Record 195: Vanavara | <Status 200>===
# ===Record 196: Banjar | <Status 200>===
# ===Record 197: Harper | <Status 200>===
# ===Record 198: Sabya | <Status 200>===
# ===Record 199: Muravlenko | <Status 200>===
# ===Record 200: Ilulissat | <Status 200>===
# ===Record 201: Aksarka | <Status 200>===
# ===Record 202: Peleduy | <Status 200>===
# ===Record 203: Camargo | <Status 200>===
# ===Record 204: Auki | <Status 200>===
# ===Record 205: Bartow | <Status 200>===
# ===Record 206: Muscat | <Status 200>===
# ===Record 207: Denpasar | <Status 200>===
# ===Record 208: Tuy hoa | <Status 200>===
# ===Record 209: Ichnya | <Status 200>===
# ===Record 210: Lexington | <Status 200>===
# ===Record 211: Praxedis guerrero | <Status 200>===
# ===Record 212: Aklera | <Status 200>===
# ===Record 213: Hobyo | <Status 200>===
# ===Record 214: Buarcos | <Status 200>===
# ===Record 215: Haghartsin | <Status 200>===
# ===<Status: 404> | Request for city "Belushya guba" was unsuccessful. Skipping...===
# ===Record 216: Podporozhye | <Status 200>===
# ===Record 217: Tabou | <Status 200>===
# ===Record 218: Soyo | <Status 200>===
# ===Record 219: Dunedin | <Status 200>===
# ===Record 220: Viedma | <Status 200>===
# ===<Status: 404> | Request for city "Paradwip" was unsuccessful. Skipping...===
# ===Record 221: Dwarka | <Status 200>===
# ===Record 222: Kathu | <Status 200>===
# ===Record 223: Pemangkat | <Status 200>===
# ===Record 224: Ashdod | <Status 200>===
# ===Record 225: Sulangan | <Status 200>===
# ===Record 226: Zemio | <Status 200>===
# ===Record 227: Koumac | <Status 200>===
# ===Record 228: Gelemso | <Status 200>===
# ===Record 229: Lobito | <Status 200>===
# ===Record 230: Kostomuksha | <Status 200>===
# ===<Status: 404> | Request for city "Nizhneyansk" was unsuccessful. Skipping...===
# ===Record 231: Vardo | <Status 200>===
# ===Record 232: Sayanogorsk | <Status 200>===
# ===Record 233: Fuerte olimpo | <Status 200>===
# ===<Status: 404> | Request for city "Rolim de moura" was unsuccessful. Skipping...===
# ===Record 234: Cuamba | <Status 200>===
# ===Record 235: Tasiilaq | <Status 200>===
# ===Record 236: Kutum | <Status 200>===
# ===Record 237: Nabire | <Status 200>===
# ===Record 238: Bluff | <Status 200>===
# ===Record 239: Willowmore | <Status 200>===
# ===Record 240: Severo-kurilsk | <Status 200>===
# ===Record 241: Shenjiamen | <Status 200>===
# ===Record 242: Konza | <Status 200>===
# ===Record 243: Saint pete beach | <Status 200>===
# ===Record 244: Boende | <Status 200>===
# ===Record 245: Matamoros | <Status 200>===
# ===<Status: 404> | Request for city "Tumannyy" was unsuccessful. Skipping...===
# ===Record 246: Ishim | <Status 200>===
# ===Record 247: Palora | <Status 200>===
# ===<Status: 404> | Request for city "Solovetskiy" was unsuccessful. Skipping...===
# ===Record 248: Kuressaare | <Status 200>===
# ===Record 249: Goderich | <Status 200>===
# ===Record 250: Araouane | <Status 200>===
# ===Record 251: Serebryansk | <Status 200>===
# ===Record 252: Loanda | <Status 200>===
# ===Record 253: Letterkenny | <Status 200>===
# ===Record 254: Codajas | <Status 200>===
# ===<Status: 404> | Request for city "Araguatins" was unsuccessful. Skipping...===
# ===Record 255: Iranshahr | <Status 200>===
# ===Record 256: Boda | <Status 200>===
# ===Record 257: Provideniya | <Status 200>===
# ===Record 258: Dhidhdhoo | <Status 200>===
# ===Record 259: Malmesbury | <Status 200>===
# ===Record 260: Tazovskiy | <Status 200>===
# ===Record 261: Lima | <Status 200>===
# ===Record 262: Kungurtug | <Status 200>===
# ===Record 263: Tshikapa | <Status 200>===
# ===Record 264: Maua | <Status 200>===
# ===Record 265: Iwanai | <Status 200>===
# ===Record 266: Adre | <Status 200>===
# ===Record 267: Ayan | <Status 200>===
# ===Record 268: Ayagoz | <Status 200>===
# ===<Status: 404> | Request for city "Illoqqortoormiut" was unsuccessful. Skipping...===
# ===Record 269: Tezu | <Status 200>===
# ===Record 270: Zhuanghe | <Status 200>===
# ===Record 271: Mahibadhoo | <Status 200>===
# ===Record 272: Khorixas | <Status 200>===
# ===Record 273: Simao | <Status 200>===
# ===<Status: 404> | Request for city "Lolua" was unsuccessful. Skipping...===
# ===Record 274: Fortuna | <Status 200>===
# ===Record 275: Lavrentiya | <Status 200>===
# ===Record 276: Hualmay | <Status 200>===
# ===Record 277: Swellendam | <Status 200>===
# ===Record 278: Yegorlykskaya | <Status 200>===
# ===<Status: 404> | Request for city "Pilao arcado" was unsuccessful. Skipping...===
# ===Record 279: Sakaraha | <Status 200>===
# ===Record 280: Nivala | <Status 200>===
# ===Record 281: Ayutla | <Status 200>===
# ===Record 282: San rafael del sur | <Status 200>===
# ===Record 283: Baghdad | <Status 200>===
# ===Record 284: Novaya lyalya | <Status 200>===
# ===Record 285: Urengoy | <Status 200>===
# ===Record 286: Kahului | <Status 200>===
# ===Record 287: Maan | <Status 200>===
# ===Record 288: Sarakhs | <Status 200>===
# ===Record 289: Wala | <Status 200>===
# ===Record 290: Lewistown | <Status 200>===
# ===Record 291: Cruz alta | <Status 200>===
# ===Record 292: Karacabey | <Status 200>===
# ===Record 293: Sesheke | <Status 200>===
# ===Record 294: Yankton | <Status 200>===
# ===Record 295: Syamzha | <Status 200>===
# ===Record 296: Jalu | <Status 200>===
# ===Record 297: Narsipatnam | <Status 200>===
# ===Record 298: Gweta | <Status 200>===
# ===Record 299: Chepareria | <Status 200>===
# ===Record 300: Shubarshi | <Status 200>===
# ===Record 301: Riyadh | <Status 200>===
# ===Record 302: Dodge city | <Status 200>===
# ===Record 303: Udachnyy | <Status 200>===
# ===Record 304: Kalemie | <Status 200>===
# ===Record 305: Kurumkan | <Status 200>===
# ===Record 306: Mecca | <Status 200>===
# ===Record 307: Kuldur | <Status 200>===
# ===<Status: 404> | Request for city "Mocambique" was unsuccessful. Skipping...===
# ===<Status: 404> | Request for city "Katha" was unsuccessful. Skipping...===
# ===Record 308: Ongole | <Status 200>===
# ===Record 309: Portales | <Status 200>===
# ===Record 310: Morondava | <Status 200>===
# ===Record 311: Farmington | <Status 200>===
# ===<Status: 404> | Request for city "Kamenskoye" was unsuccessful. Skipping...===
# ===Record 312: Katobu | <Status 200>===
# ===Record 313: New norfolk | <Status 200>===
# ===Record 314: Bireun | <Status 200>===
# ===Record 315: Shubarkuduk | <Status 200>===
# ===Record 316: Mersin | <Status 200>===
# ===Record 317: Vanimo | <Status 200>===
# ===Record 318: Ukiah | <Status 200>===
# ===Record 319: Pangnirtung | <Status 200>===
# ===Record 320: Carahue | <Status 200>===
# ===Record 321: Pocone | <Status 200>===
# ===Record 322: Sugod | <Status 200>===
# ===Record 323: Bonfim | <Status 200>===
# ===<Status: 404> | Request for city "Vaitupu" was unsuccessful. Skipping...===
# ===Record 324: Gorontalo | <Status 200>===
# ===Record 325: Kurayoshi | <Status 200>===
# ===Record 383: San policarpo | <Status 200>===
# ===Record 384: Lata | <Status 200>===
# ===Record 385: Hasaki | <Status 200>===
# ===Record 386: Honiara | <Status 200>===
# ===Record 387: Dryden | <Status 200>===
# ===Record 388: Mgandu | <Status 200>===
# ===Record 389: Haines junction | <Status 200>===
# ===Record 390: Palma del rio | <Status 200>===
# ===Record 391: Kalanguy | <Status 200>===
# ===Record 392: Rikitea | <Status 200>===
# ===Record 393: Dingzhou | <Status 200>===
# ===Record 394: Mehamn | <Status 200>===
# ===Record 395: Betong | <Status 200>===
# ===Record 396: Bilma | <Status 200>===
# ===Record 397: Parintins | <Status 200>===
# ===Record 398: Cape town | <Status 200>===
# ===<Status: 404> | Request for city "Grand river south east" was unsuccessful. Skipping...===
# ===Record 399: Sann | <Status 200>===
# ===Record 400: Pandan | <Status 200>===
# ===Record 401: Porto santo | <Status 200>===
# ===Record 402: Asau | <Status 200>===
# ===Record 403: Zhezkazgan | <Status 200>===
# ===Record 404: Kamen-na-obi | <Status 200>===
# ===Record 405: Flinders | <Status 200>===
# ===Record 406: Donskoye | <Status 200>===
# ===Record 407: Sawakin | <Status 200>===
# ===Record 408: Alice town | <Status 200>===
# ===Record 409: Oppdal | <Status 200>===
# ===Record 410: Omboue | <Status 200>===
# ===Record 411: Kormilovka | <Status 200>===
# ===Record 412: Fort smith | <Status 200>===
# ===Record 413: Manicore | <Status 200>===
# ===Record 414: Caraballeda | <Status 200>===
# ===Record 415: Carbonia | <Status 200>===
# ===Record 416: Kabinda | <Status 200>===
# ===Record 417: Roma | <Status 200>===
# ===Record 418: Smolenka | <Status 200>===
# ===Record 419: Wanning | <Status 200>===
# ===Record 420: Sarahan | <Status 200>===
# ===Record 421: Deputatskiy | <Status 200>===
# ===Record 422: Walvis bay | <Status 200>===
# ===Record 423: Vitim | <Status 200>===
# ===Record 424: Micheweni | <Status 200>===
# ===Record 425: Kamen-rybolov | <Status 200>===
# ===Record 426: Sai buri | <Status 200>===
# ===Record 427: Trujillo | <Status 200>===
# ===Record 428: Mabaruma | <Status 200>===
# ===Record 429: Puebloviejo | <Status 200>===
# ===Record 430: Belvedere marittimo | <Status 200>===
# ===Record 431: Kindu | <Status 200>===
# ===<Status: 404> | Request for city "Taolanaro" was unsuccessful. Skipping...===
# ===<Status: 404> | Request for city "Bolungarvik" was unsuccessful. Skipping...===
# ===Record 432: Tangwani | <Status 200>===
# ===Record 433: Chiredzi | <Status 200>===
# ===Record 434: Lianzhou | <Status 200>===
# ===Record 435: Erzin | <Status 200>===
# ===Record 436: Tiverton | <Status 200>===
# ===<Status: 404> | Request for city "Zhanatas" was unsuccessful. Skipping...===
# ===Record 437: Moussoro | <Status 200>===
# ===Record 438: Udimskiy | <Status 200>===
# ===<Status: 404> | Request for city "Tsihombe" was unsuccessful. Skipping...===
# ===Record 439: Nushki | <Status 200>===
# ===Record 440: Kadaya | <Status 200>===
# ===Record 441: Tual | <Status 200>===
# ===Record 442: Baisha | <Status 200>===
# ===Record 443: Chivacoa | <Status 200>===
# ===Record 444: Corner brook | <Status 200>===
was unsuccessful. Skipping...===
# ===<Status: 404> | Request for city "Wulanhaote" was unsuccessful. Skipping...===
# ===Record 508: Sozimskiy | <Status 200>===
# ===Record 509: Inhambane | <Status 200>===
# ===Record 510: Mar del plata | <Status 200>===
# ===Record 511: Bilibino | <Status 200>===
# ===Record 512: Beidao | <Status 200>===
# ===Record 513: Mukhen | <Status 200>===
# ===Record 514: Lusambo | <Status 200>===
# ===Record 515: Caruray | <Status 200>===
# ===<Status: 404> | Request for city "Inderborskiy" was unsuccessful. Skipping...===
# ===Record 516: Zhumadian | <Status 200>===
# ===Record 517: Rockland | <Status 200>===
# ===Record 518: Elat | <Status 200>===
# ===Record 519: Turbat | <Status 200>===
# ===Record 520: Kushmurun | <Status 200>===
# ===Record 521: Zacualpan | <Status 200>===
# ===Record 522: Thompson | <Status 200>===
# ===Record 523: Porto novo | <Status 200>===
# ===Record 524: Radhanpur | <Status 200>===
# ===Record 525: Kemijarvi | <Status 200>===
# ===Record 526: Nuevo progreso | <Status 200>===
# ===Record 527: Batemans bay | <Status 200>===
# ===Record 528: Hibbing | <Status 200>===
# ===Record 529: Nikki | <Status 200>===
# ===Record 530: Klaksvik | <Status 200>===
# ===Record 531: Fallon | <Status 200>===
# ===Record 532: Baykit | <Status 200>===
# ===Record 533: Hilo | <Status 200>===
# ===<Status: 404> | Request for city "Valjala" was unsuccessful. Skipping...===
# ===Record 534: Cumra | <Status 200>===
# ===Record 535: Barstow | <Status 200>===
# ===Record 536: Owando | <Status 200>===
# ===Record 537: Port augusta | <Status 200>===
# ===Record 538: Dibulla | <Status 200>===
# ===Record 539: Tecoanapa | <Status 200>===
# ===Record 540: Sao joao da barra | <Status 200>===
# ===Record 541: Taksimo | <Status 200>===
# ===Record 542: Lesosibirsk | <Status 200>===
# ===Record 543: Greenville | <Status 200>===
# ===Record 544: Kieta | <Status 200>===
# ===Record 545: Skovorodino | <Status 200>===
# ===Record 546: Besancon | <Status 200>===
# ===Record 547: Atambua | <Status 200>===
# ===Record 548: Nedjo | <Status 200>===
# ===Record 549: Mengcheng | <Status 200>===
# ===Record 550: Kaitangata | <Status 200>===
# ===Record 551: General pico | <Status 200>===
# ===Record 552: Sovetskiy | <Status 200>===
# ===Record 553: Kloulklubed | <Status 200>===
# ===Record 554: Mvangue | <Status 200>===
# ===Record 555: Shizunai | <Status 200>===
# ===Record 556: Saquarema | <Status 200>===
# ===Record 557: Sinegorye | <Status 200>===
# ===Record 558: Svetlyy | <Status 200>===
# ===Record 559: Jacareacanga | <Status 200>===
# ===Record 560: Balaguer | <Status 200>===
# ===Record 561: Zambezi | <Status 200>===
# ===Record 562: Trelew | <Status 200>===
# ===Record 563: Wakkanai | <Status 200>===
# ===Record 564: Gamboma | <Status 200>===
# ===Record 565: Sitka | <Status 200>===
# ===Record 566: San patricio | <Status 200>===
# ===Record 567: Lapeer | <Status 200>===
# ===Record 568: Vestmannaeyjar | <Status 200>===
# ===Record 569: Santa isabel do rio negro | <Status 200>===
# ===Record 638: Granja | <Status 200>===
# ===Record 639: Barranca | <Status 200>===
# ===Record 640: Saiha | <Status 200>===
# ===Record 641: Cayenne | <Status 200>===
# ===Record 642: Biu | <Status 200>===
# ===Record 643: Saskylakh | <Status 200>===
# ===Record 644: Tumpat | <Status 200>===
# ===Record 645: Beruwala | <Status 200>===
# ===Record 646: Kipini | <Status 200>===
# ===Record 647: Ourossogui | <Status 200>===
# ===Record 648: Pingxiang | <Status 200>===
# ===Record 649: Mareeba | <Status 200>===
# ===Record 650: Danville | <Status 200>===
# ===Record 651: Luderitz | <Status 200>===
# ===Record 652: La orilla | <Status 200>===
# ===<Status: 404> | Request for city "Ituni" was unsuccessful. Skipping...===
# ===Record 653: Cabedelo | <Status 200>===
# ===Record 654: Salaga | <Status 200>===
# ===<Status: 404> | Request for city "Acuna" was unsuccessful. Skipping...===
# ===<Status: 404> | Request for city "Cheuskiny" was unsuccessful. Skipping...===
# ===<Status: 404> | Request for city "Tingrela" was unsuccessful. Skipping...===
# ===Record 655: Bisho | <Status 200>===
# ===Record 656: Warwick | <Status 200>===
# ===Record 657: Kisesa | <Status 200>===
# ===Record 658: Khasan | <Status 200>===
# ===Record 659: Ankazobe | <Status 200>===
# ===Record 660: Suntar | <Status 200>===
# ===Record 661: Yokadouma | <Status 200>===
# ===Record 662: Progreso | <Status 200>===
# ===Record 663: Aurangabad | <Status 200>===
# ===Record 664: Salekhard | <Status 200>===
# ===Record 665: Dauriya | <Status 200>===
# ===Record 666: Cape coast | <Status 200>===
# ===Record 667: Inirida | <Status 200>===
# ===Record 668: Adrar | <Status 200>===
# ===Record 669: Paamiut | <Status 200>===
# ===Record 670: Kiama | <Status 200>===
# ===Record 671: Krasnoselkup | <Status 200>===
# ===<Status: 404> | Request for city "Urfa" was unsuccessful. Skipping...===
# ===<Status: 404> | Request for city "Artyk" was unsuccessful. Skipping...===
# ===Record 672: Dali | <Status 200>===
# ===Record 673: Alasehir | <Status 200>===
# ===Record 674: Saqqez | <Status 200>===
# ===Record 675: Kamenz | <Status 200>===
# ===Record 676: Kirakira | <Status 200>===
# ===Record 677: Mullingar | <Status 200>===
# ===Record 678: Betioky | <Status 200>===
# ===Record 679: Naberera | <Status 200>===
# ===Record 680: Necochea | <Status 200>===
# ===Record 681: Watertown | <Status 200>===
# ===<Status: 404> | Request for city "Ye" was unsuccessful. Skipping...===
# ===Record 682: Madison | <Status 200>===
# ===<Status: 404> | Request for city "Ust-bolsheretsk" was unsuccessful. Skipping...===
# ===<Status: 404> | Request for city "Barawe" was unsuccessful. Skipping...===
# ===<Status: 404> | Request for city "Meyungs" was unsuccessful. Skipping...===
# ===Record 683: Kumo | <Status 200>===
# ===Record 684: Vershino-darasunskiy | <Status 200>===
# ===<Status: 200> | Request for city "Manjacaze" was unsuccessful. Skipping...===
# ===<Status: 404> | Request for city "Leghorn" was unsuccessful. Skipping...===
# ===Record 685: Harindanga | <Status 200>===
# ===Record 686: Canazas | <Status 200>===
# ===Record 687: Loukhi | <Status 200>===
# ===Record 688: Biscarrosse | <Status 200>===
# ===Record 689: Praya | <Status 200>===
# ===<Status: 404> | Request for city "Fort saint john" was unsuccessful. Skipping...===
# ===Record 690: Badarwas | <Status 200>===
# ===Record 691: Nimbahera | <Status 200>===
# ===<Status: 404> | Request for city "Chagda" was unsuccessful. Skipping...===
# ===Record 692: Gao | <Status 200>===
# ===Record 693: Oktyabrskiy | <Status 200>===
# ===Record 694: Samur | <Status 200>===
# ===<Status: 404> | Request for city "Sentyabrskiy" was unsuccessful. Skipping...===
# ===Record 695: Alyangula | <Status 200>===
# ===Record 696: Yevpatoriya | <Status 200>===
# ===Record 697: Cururupu | <Status 200>===
# ===<Status: 404> | Request for city "Chiconautla" was unsuccessful. Skipping...===
# ===Record 698: Tenenkou | <Status 200>===
# ===Record 699: Kapaa | <Status 200>===
# ===Record 700: Payyannur | <Status 200>===
# ===Record 701: Dawei | <Status 200>===
# ===Record 702: Cradock | <Status 200>===
# ===Record 703: Middelkerke | <Status 200>===
# ===<Status: 404> | Request for city "Coalcoman" was unsuccessful. Skipping...===
# ===Record 704: Collie | <Status 200>===
# ===Record 705: Santa marta | <Status 200>===
# ===Record 706: Margate | <Status 200>===
# ===Record 707: Alugan | <Status 200>===
# ===Record 708: Karratha | <Status 200>===
# ===Record 709: Marrakesh | <Status 200>===
# ===Record 710: Rozhyshche | <Status 200>===
# ===Record 711: Terenos | <Status 200>===
# ===Record 712: Negombo | <Status 200>===
# ===Record 713: Chuy | <Status 200>===
# ===Record 714: Betsiamites | <Status 200>===
# ===Record 715: Castro | <Status 200>===
# ===Record 716: Selma | <Status 200>===
# ===Record 717: Ponta delgada | <Status 200>===
# ===<Status: 404> | Request for city "Khonuu" was unsuccessful. Skipping...===
# ===Record 718: Pitimbu | <Status 200>===
# ===Record 719: Ada | <Status 200>===
# ===Record 720: Constitucion | <Status 200>===
# ===<Status: 404> | Request for city "Jiddah" was unsuccessful. Skipping...===
# ===Record 721: Mayumba | <Status 200>===
# ===Record 722: Tucurui | <Status 200>===
# ===Record 723: Berlevag | <Status 200>===
# ===Record 724: Iquitos | <Status 200>===
# ===Record 725: Pacific grove | <Status 200>===
# ===Record 726: Agnibilekrou | <Status 200>===
# ===Record 727: Vestmanna | <Status 200>===
# ===Record 728: Hay river | <Status 200>===
# ===Record 729: Kisangani | <Status 200>===
# ===Record 730: Chapleau | <Status 200>===
# ===Record 731: Boueni | <Status 200>===
# ===Record 732: Yaring | <Status 200>===
# ===Record 733: Belyy yar | <Status 200>===
# ===Record 734: Xucheng | <Status 200>===
# ===Record 735: Diphu | <Status 200>===
# ===Record 736: Palauig | <Status 200>===
# ===Record 737: Marystown | <Status 200>===
# ===Record 738: Mackenzie | <Status 200>===
# ===Record 739: Antofagasta | <Status 200>===
# ===Record 740: Santiago | <Status 200>===
# ===Record 741: Kiunga | <Status 200>===
# ===Record 742: Svetlaya | <Status 200>===
# ===Record 743: Jingdezhen | <Status 200>===
# ===Record 744: Barguzin | <Status 200>===
# ===Record 745: Hecun | <Status 200>===
# ===<Status: 404> | Request for city "Anar darreh" was unsuccessful. Skipping...===
# ===Record 746: Jagdalpur | <Status 200>===
# ===<Status: 404> | Request for city "Of" was unsuccessful. Skipping...===
# ===Record 747: Gigant | <Status 200>===
# ===Record 748: Staryy nadym | <Status 200>===
# ===Record 813: Aykhal | <Status 200>===
# ===Record 814: Ulladulla | <Status 200>===
# ===Record 815: Daye | <Status 200>===
# ===<Status: 404> | Request for city "Mutsamudu" was unsuccessful. Skipping...===
# ===Record 816: Tingo maria | <Status 200>===
# ===Record 817: Ames | <Status 200>===
# ===Record 818: Agadez | <Status 200>===
# ===Record 819: Brandon | <Status 200>===
# ===Record 820: Kaeo | <Status 200>===
# ===Record 821: Traverse city | <Status 200>===
# ===Record 822: Tashigang | <Status 200>===
# ===Record 823: Brookhaven | <Status 200>===
# ===Record 824: Norman wells | <Status 200>===
# ===Record 825: Burnie | <Status 200>===
# ===Record 826: Bud | <Status 200>===
# ===Record 827: Krasnodon | <Status 200>===
# ===Record 828: Piripiri | <Status 200>===
# ===Record 829: Bella union | <Status 200>===
# ===Record 830: Yaan | <Status 200>===
# ===<Status: 404> | Request for city "Umm ruwabah" was unsuccessful. Skipping...===
# ===<Status: 404> | Request for city "Fevralsk" was unsuccessful. Skipping...===
# ===Record 831: Can | <Status 200>===
# ===Record 832: Grootfontein | <Status 200>===
# ===Record 833: Kropotkin | <Status 200>===
# ===<Status: 404> | Request for city "Mys shmidta" was unsuccessful. Skipping...===
# ===Record 834: Vostok | <Status 200>===
# ===Record 835: Busselton | <Status 200>===
# ===Record 836: Esmeraldas | <Status 200>===
# ===Record 837: Nouadhibou | <Status 200>===
# ===Record 838: Bulungu | <Status 200>===
# ===Record 839: Charleston | <Status 200>===
# ===Record 840: Petropavlovsk-kamchatskiy | <Status 200>===
# ===<Status: 404> | Request for city "Autlan" was unsuccessful. Skipping...===
# ===Record 841: Isangel | <Status 200>===
# ===Record 842: Sambava | <Status 200>===
# ===Record 843: Bambanglipuro | <Status 200>===
# ===Record 844: Khandyga | <Status 200>===
# ===Record 845: Touros | <Status 200>===
# ===Record 846: Chernyshevskiy | <Status 200>===
# ===Record 847: Zacualtipan | <Status 200>===
# ===Record 848: Maebaru | <Status 200>===
# ===Record 849: Masuguru | <Status 200>===
# ===Record 850: Morant bay | <Status 200>===
# ===Record 851: Mutoko | <Status 200>===
# ===Record 852: Catuday | <Status 200>===
# ===Record 853: Mindelo | <Status 200>===
# ===Record 854: Vung tau | <Status 200>===
# ===Record 855: East london | <Status 200>===
# ===Record 856: Axim | <Status 200>===
# ===Record 857: Vaini | <Status 200>===
# ===Record 858: Teguldet | <Status 200>===
# ===Record 859: Port hardy | <Status 200>===
# ===Record 860: Jibuti | <Status 200>===
# ===Record 861: Rocha | <Status 200>===
# ===Record 862: Umm kaddadah | <Status 200>===
# ===Record 863: Bad doberan | <Status 200>===
# ===Record 864: Manzhouli | <Status 200>===
# ===Record 865: Mtinko | <Status 200>===
# ===Record 866: Carlsbad | <Status 200>===
# ===Record 867: Palmerston | <Status 200>===
# ===Record 868: Zharkent | <Status 200>===
# ===Record 869: Maarianhamina | <Status 200>===
# ===Record 870: Sam roi yot | <Status 200>===
# ===Record 871: Wilmington island | <Status 200>===
# ===Record 872: Tukrah | <Status 200>===
# ===Record 873: Yangambi | <Status 200>===
# ===Record 874: Changji | <Status 200>===
# ===Record 875: Cameta | <Status 200>===
# ===Record 876: Hare bay | <Status 200>===
# ===Record 877: Inzhavino | <Status 200>===
# ===Record 878: Umm lajj | <Status 200>===
# ===Record 879: Richards bay | <Status 200>===
# ===Record 880: Hole narsipur | <Status 200>===
# ===Record 881: Neryungri | <Status 200>===
# ===Record 882: Alakurtti | <Status 200>===
# ===Record 883: Malindi | <Status 200>===
# ===Record 884: Verkhoyansk | <Status 200>===
# ===Record 885: Makakilo city | <Status 200>===
# ===Record 886: Victoria point | <Status 200>===
# ===Record 887: Aripuana | <Status 200>===
# ===Record 888: Xunchang | <Status 200>===
# ===Record 889: Husavik | <Status 200>===
# ===Record 890: Circleville | <Status 200>===
# ===Record 891: Port alfred | <Status 200>===
# ===Record 892: Kapit | <Status 200>===
# ===Record 893: Cotonou | <Status 200>===
# ===Record 894: Caravelas | <Status 200>===
# ===Record 895: Hermanus | <Status 200>===
# ===Record 896: Ekimchan | <Status 200>===
# ===Record 897: Antanifotsy | <Status 200>===
# ===Record 898: Mwene-ditu | <Status 200>===
# ===Record 899: Sile | <Status 200>===
# ===Record 900: Hojai | <Status 200>===
# ===Record 901: Van buren | <Status 200>===
# ===Record 902: Ust-nera | <Status 200>===
# ===Record 903: Shuangcheng | <Status 200>===
# ===Record 904: Qeshm | <Status 200>===
# ===Record 905: Porbandar | <Status 200>===
# ===Record 906: Portland | <Status 200>===
# ===Record 907: Laguna | <Status 200>===
# ===Record 908: Yar-sale | <Status 200>===
# ===Record 909: Rochegda | <Status 200>===
# ===Record 910: Merauke | <Status 200>===
# ===Record 911: Desterro | <Status 200>===
# ===Record 912: Ostrovnoy | <Status 200>===
# ===Record 913: Lai | <Status 200>===
# ===Record 914: Nizhnekamsk | <Status 200>===
# ===<Status: 404> | Request for city "Phan rang" was unsuccessful. Skipping...===
# ===Record 915: Westport | <Status 200>===
# ===Record 916: Xicotencatl | <Status 200>===
# ===Record 917: El alto | <Status 200>===
# ===Record 918: Torit | <Status 200>===
# ===Record 919: Ingham | <Status 200>===
# ===<Status: 404> | Request for city "Lephepe" was unsuccessful. Skipping...===
# ===Record 920: Saintes | <Status 200>===
# ===Record 921: Waddan | <Status 200>===
# ===Record 922: Diveyevo | <Status 200>===
# ===<Status: 404> | Request for city "Chelyabinsk-70" was unsuccessful. Skipping...===
# ===Record 923: Vetluga | <Status 200>===
# ===Record 924: Nikolsk | <Status 200>===
# ===Record 925: Vyshestebliyevskaya | <Status 200>===
# ===Record 926: Chicama | <Status 200>===
# ===<Status: 404> | Request for city "Dubenskiy" was unsuccessful. Skipping...===
# ===Record 927: Uyar | <Status 200>===
# ===Record 928: Waitati | <Status 200>===
# ===Record 929: Yakima | <Status 200>===
# ===Record 930: Malhargarh | <Status 200>===
# ===Record 931: Bambous virieux | <Status 200>===
# ===Record 932: Conakry | <Status 200>===
# ===Record 933: Kedrovyy | <Status 200>===
# ===Record 934: Bom jesus do galho | <Status 200>===
# ===Record 935: Ishigaki | <Status 200>===
# ===Record 936: Reconquista | <Status 200>===
# ===Record 937: Krasnoyarsk | <Status 200>===
# ===Record 938: Santa rosa | <Status 200>===
# ===Record 939: Tiznit | <Status 200>===
# ===Record 940: Tulskiy | <Status 200>===
# ===Record 941: Ko samui | <Status 200>===
# ===<Status: 404> | Request for city "Milingimbi" was unsuccessful. Skipping...===
# ===Record 942: Fort nelson | <Status 200>===
# ===Record 943: Moose factory | <Status 200>===
# ===Record 944: Erdenet | <Status 200>===
# ===<Status: 404> | Request for city "Viligili" was unsuccessful. Skipping...===
# ===Record 945: Priargunsk | <Status 200>===
# ===Record 946: Acari | <Status 200>===
# ===Record 947: Bogorodskoye | <Status 200>===
# ===Record 948: San cristobal | <Status 200>===
# ===Record 949: Kearney | <Status 200>===
# ===Record 950: Carauari | <Status 200>===
# ===<Status: 404> | Request for city "Attawapiskat" was unsuccessful. Skipping...===
# ===Record 951: Nikolskoye | <Status 200>===
# ===Record 952: Nichinan | <Status 200>===
# ===Record 953: Sassandra | <Status 200>===
# ===Record 954: Broken hill | <Status 200>===
# ===<Status: 404> | Request for city "Ondorhaan" was unsuccessful. Skipping...===
# ===Record 955: Magadan | <Status 200>===
# ===Record 956: Havoysund | <Status 200>===
# ===Record 957: Cidreira | <Status 200>===
# ===Record 958: Tarauaca | <Status 200>===
# ===Record 959: Rio gallegos | <Status 200>===
# ===Record 960: Mount gambier | <Status 200>===
# ===Record 961: Prado | <Status 200>===
# ===Record 962: Cookeville | <Status 200>===
# ===Record 963: Hede | <Status 200>===
# ===Record 964: Lacey | <Status 200>===
# ===Record 965: Rudbar | <Status 200>===
# ===Record 966: Cascais | <Status 200>===
# ===Record 967: Petrovsk | <Status 200>===
# ===Record 968: Lufilufi | <Status 200>===
# ===Record 969: Nizwa | <Status 200>===
# ...
# ===Record 1058: Saint-anselme | <Status 200>===
# ===Record 1059: Beringovskiy | <Status 200>===
# ===Record 1060: Jennings | <Status 200>===
# ===Record 1061: Ekibastuz | <Status 200>===
# ===Record 1062: Teahupoo | <Status 200>===
# ===Record 1063: Cockburn town | <Status 200>===
# ===Record 1064: Khaniotis | <Status 200>===
# ===Record 1065: Maroantsetra | <Status 200>===
# ===<Status: 404> | Request for city "Tabialan" was unsuccessful. Skipping...===
# ===Record 1066: Barbastro | <Status 200>===
# ===Record 1067: Ranong | <Status 200>===
# ===Record 1068: Pouembout | <Status 200>===
# ===Record 1069: Dong xoai | <Status 200>===
# ===Record 1070: Thyboron | <Status 200>===
# ===Record 1071: Eisiskes | <Status 200>===
# ===Record 1072: Khandbari | <Status 200>===
# ===Record 1073: Matara | <Status 200>===
# ===Record 1074: Acajutla | <Status 200>===
# ===Record 1075: Moroto | <Status 200>===
# ===Record 1076: Daru | <Status 200>===
# ===Record 1077: Iracoubo | <Status 200>===
# ===<Status: 404> | Request for city "Nguiu" was unsuccessful. Skipping...===
# ===Record 1078: Qasigiannguit | <Status 200>===
# ===Record 1079: Avarua | <Status 200>===
# ===Record 1140: Morros | <Status 200>===
# ===Record 1141: Mosquera | <Status 200>===
# ===Record 1142: Rio grande | <Status 200>===
# ===Record 1143: Ozernovskiy | <Status 200>===
# ===Record 1144: Kashi | <Status 200>===
# ===Record 1145: Muli | <Status 200>===
# ===Record 1146: Bonthe | <Status 200>===
# ===Record 1147: Abay | <Status 200>===
# ===Record 1148: Sydney | <Status 200>===
# ===Record 1149: Gladstone | <Status 200>===
# ===<Status: 404> | Request for city "Karkaralinsk" was unsuccessful. Skipping...===
# ===Record 1150: Bengkulu | <Status 200>===
# ===Record 1151: Xining | <Status 200>===
# ===Record 1152: Alta floresta | <Status 200>===
# ===Record 1153: Olindina | <Status 200>===
# ===Record 1154: Padang | <Status 200>===
# ===<Status: 404> | Request for city "Canitas" was unsuccessful. Skipping...===
# ===Record 1155: Anloga | <Status 200>===
# ===Record 1156: Lillooet | <Status 200>===
# ===Record 1157: Lae | <Status 200>===
# ===Record 1158: Muroran | <Status 200>===
# ===Record 1159: Pamfila | <Status 200>===
# ===Record 1160: Vilcun | <Status 200>===
# ===Record 1161: Sao borja | <Status 200>===
# ===Record 1162: Golden | <Status 200>===
# ===Record 1163: Atikokan | <Status 200>===
# ===Record 1164: Ostrogozhsk | <Status 200>===
# ===Record 1165: Nalut | <Status 200>===
# ===Record 1166: Kuusamo | <Status 200>===
# ===Record 1167: Ushuaia | <Status 200>===
# ===Record 1168: Kodinar | <Status 200>===
# ===Record 1169: Kendari | <Status 200>===
# ===Record 1170: Krasnooktyabrskiy | <Status 200>===
# ===Record 1171: Castanos | <Status 200>===
# ===Record 1172: Abrego | <Status 200>===
# ===Record 1173: Tiksi | <Status 200>===
# ===Record 1174: Luchegorsk | <Status 200>===
# ===Record 1175: Stony plain | <Status 200>===
# ===Record 1176: Arcachon | <Status 200>===
# ===Record 1177: Cuervos | <Status 200>===
# ===Record 1178: Puerto penasco | <Status 200>===
# ===Record 1179: Ahuimanu | <Status 200>===
# ===Record 1180: Hithadhoo | <Status 200>===
# ===Record 1181: Saint-leu | <Status 200>===
# ===Record 1182: Monte patria | <Status 200>===
# ===Record 1183: Sioux lookout | <Status 200>===
# ===Record 1184: Muborak | <Status 200>===
# ===<Status: 404> | Request for city "Warqla" was unsuccessful. Skipping...===
# ===Record 1185: Saint-francois | <Status 200>===
# ===Record 1186: Gaya | <Status 200>===
# ===Record 1187: Kidal | <Status 200>===
# ===Record 1188: San andres | <Status 200>===
# ===Record 1189: Aswan | <Status 200>===
# ===Record 1190: Antalaha | <Status 200>===
# ===Record 1191: Aksu | <Status 200>===
# ===Record 1192: Makubetsu | <Status 200>===
# ===Record 1193: Jumla | <Status 200>===
# ===Record 1194: Chadiza | <Status 200>===
# ===Record 1195: Taian | <Status 200>===
# ===Record 1196: Mayfield | <Status 200>===
# ===Record 1197: Pahrump | <Status 200>===
# ===<Status: 404> | Request for city "Bargal" was unsuccessful. Skipping...===
# ===Record 1198: Ridgecrest | <Status 200>===
# ===Record 1199: Podgornoye | <Status 200>===
# ===Record 1200: Carlos chagas | <Status 200>===
# ===Record 1201: Dudinka | <Status 200>===
# ===Record 1202: Batagay-alyta | <Status 200>===
# ===Record 1203: Williamsburg | <Status 200>===
# ===Record 1204: Nemuro | <Status 200>===
# ===Record 1205: Moses lake | <Status 200>===
# ===Record 1206: Yamada | <Status 200>===
# ===Record 1207: Beloha | <Status 200>===
# ===Record 1208: Cabras | <Status 200>===
# ===Record 1209: Moscow | <Status 200>===
# ===Record 1210: Shilong | <Status 200>===
# ===Record 1211: Verkhnyaya inta | <Status 200>===
# ===Record 1212: Farafangana | <Status 200>===
# ===Record 1213: Oriximina | <Status 200>===
# ===Record 1214: Hyeres | <Status 200>===
# ===<Status: 404> | Request for city "Yialos" was unsuccessful. Skipping...===
# ===Record 1215: Xichang | <Status 200>===
# ===Record 1216: Rodos | <Status 200>===
# ===Record 1217: Akhalgori | <Status 200>===
# ===Record 1218: Itaituba | <Status 200>===
# ===Record 1219: Bonavista | <Status 200>===
# ===Record 1220: Pasni | <Status 200>===
# ===Record 1221: Vagur | <Status 200>===
# ===Record 1222: Formosa | <Status 200>===
# ===Record 1223: Olavarria | <Status 200>===
# ===Record 1224: Zhigansk | <Status 200>===
# ===Record 1225: Goryachegorsk | <Status 200>===
# ===Record 1226: Santa vitoria do palmar | <Status 200>===
# ===Record 1227: Samfya | <Status 200>===
# ===Record 1228: Bredasdorp | <Status 200>===
# ===Record 1229: Pointe michel | <Status 200>===
# ===Record 1230: Hukuntsi | <Status 200>===
# ===Record 1231: Port elizabeth | <Status 200>===
# ===Record 1232: Ismailia | <Status 200>===
# ===Record 1233: Punta arenas | <Status 200>===
# ===Record 1234: Manado | <Status 200>===
# ===Record 1235: Port said | <Status 200>===
# ===Record 1236: Burgstadt | <Status 200>===
# ===Record 1237: Mazabuka | <Status 200>===
# ===<Status: 404> | Request for city "Mudyuga" was unsuccessful. Skipping...===
# ===Record 1238: Panjab | <Status 200>===
# ===Record 1239: Takoradi | <Status 200>===
# ===Record 1240: Laminusa | <Status 200>===
# ===Record 1241: Praia da vitoria | <Status 200>===
# ===Record 1242: Alcudia | <Status 200>===
# ===Record 1243: Kabwe | <Status 200>===
# ===Record 1244: Altay | <Status 200>===
# ===Record 1245: Truth or consequences | <Status 200>===
# ===Record 1246: San pedro de macoris | <Status 200>===
# ===Record 1247: Pisco | <Status 200>===
# ===Record 1248: Chandbali | <Status 200>===
# ===Record 1249: Kolpny | <Status 200>===
# ===Record 1250: Sao mateus | <Status 200>===
# ===Record 1251: Tokur | <Status 200>===
# ===Record 1252: Felipe carrillo puerto | <Status 200>===
# ===Record 1253: Mayo | <Status 200>===
# ===<Status: 404> | Request for city "Saleaula" was unsuccessful. Skipping...===
# ===Record 1254: Bealanana | <Status 200>===
# ===Record 1255: Trincomalee | <Status 200>===
# ===Record 1256: Mataura | <Status 200>===
# ===Record 1257: Camacha | <Status 200>===
# ===Record 1258: Sabha | <Status 200>===
# ===Record 1259: Ilorin | <Status 200>===
# ===Record 1260: Gamba | <Status 200>===
# ===<Status: 404> | Request for city "Higuey" was unsuccessful. Skipping...===
# ===Record 1261: Visnes | <Status 200>===
# ===Record 1262: Porlamar | <Status 200>===
# ===Record 1263: Atuona | <Status 200>===
# ===Record 1264: Aljezur | <Status 200>===
# ===Record 1265: Marsaxlokk | <Status 200>===
# ===Record 1266: Kuching | <Status 200>===
# ===<Status: 404> | Request for city "Tabiauea" was unsuccessful. Skipping...===
# ===Record 1267: Fayaoue | <Status 200>===
# ===Record 1268: Griffith | <Status 200>===
# ===<Status: 404> | Request for city "Andevoranto" was unsuccessful. Skipping...===
# ===Record 1269: Palmer | <Status 200>===
# ===Record 1270: Kuruman | <Status 200>===
# ===Record 1271: Brigantine | <Status 200>===
# ===Record 1272: Port keats | <Status 200>===
# ===Record 1273: Shadrinsk | <Status 200>===
# ===Record 1274: Te anau | <Status 200>===
# ===Record 1275: Marsa matruh | <Status 200>===
# ===Record 1276: Havelock | <Status 200>===
# ===Record 1277: Hat yai | <Status 200>===
# ===Record 1278: Faya | <Status 200>===
# ===Record 1279: Flin flon | <Status 200>===
# ===Record 1280: Hinton | <Status 200>===
# ===Record 1281: Rabo de peixe | <Status 200>===
# ===Record 1282: Kudahuvadhoo | <Status 200>===
# ===Record 1283: Amazar | <Status 200>===
# ===Record 1284: Mulege | <Status 200>===
# ===Record 1285: Dikson | <Status 200>===
# ===Record 1286: Nome | <Status 200>===
# ===Record 1287: Raton | <Status 200>===
# ===Record 1288: Ribeira brava | <Status 200>===
# ===Record 1289: Mogoytuy | <Status 200>===
# ===Record 1290: Alofi | <Status 200>===
# ===Record 1291: Muzambinho | <Status 200>===
# ===Record 1292: Bayanday | <Status 200>===
# ===Record 1293: Abbeville | <Status 200>===
# ===Record 1294: Mao | <Status 200>===
# ===Record 1295: Umea | <Status 200>===
# ===Record 1296: Sinnamary | <Status 200>===
# ===Record 1297: Hoshcha | <Status 200>===
# ===Record 1298: Billings | <Status 200>===
# ===Record 1299: Lagoa | <Status 200>===
# ===Record 1300: Emerald | <Status 200>===
# ===Record 1301: Vila franca do campo | <Status 200>===
# ===Record 1302: Ibra | <Status 200>===
# ===Record 1303: Cap malheureux | <Status 200>===
# ===Record 1304: Opuwo | <Status 200>===
# ===Record 1305: Aklavik | <Status 200>===
# ===Record 1306: Codrington | <Status 200>===
# ===Record 1307: Mandali | <Status 200>===
# ===Record 1308: Henties bay | <Status 200>===
# ===Record 1309: La union | <Status 200>===
# ===Record 1310: Saint-pierre | <Status 200>===
# ===Record 1311: Corinto | <Status 200>===
# ===Record 1312: Halifax | <Status 200>===
# ===Record 1313: Poya | <Status 200>===
# ===Record 1314: Saldanha | <Status 200>===
# ===Record 1315: Vao | <Status 200>===
# ===Record 1316: Taoudenni | <Status 200>===
# ===Record 1317: Yuryevets | <Status 200>===
# ===Record 1318: Juneau | <Status 200>===
# ===<Status: 404> | Request for city "Umzimvubu" was unsuccessful. Skipping...===
# ===Record 1319: Nyurba | <Status 200>===
# ===Record 1320: Lakes entrance | <Status 200>===
# ===<Status: 404> | Request for city "Toliary" was unsuccessful. Skipping...===
# ===Record 1321: Ugoofaaru | <Status 200>===
# ===Record 1322: Sur | <Status 200>===
# ===Record 1323: Souillac | <Status 200>===
# ===Record 1324: Petropavl | <Status 200>===
# ===Record 1325: Lingyuan | <Status 200>===
# ===<Status: 404> | Request for city "Ust-kamchatsk" was unsuccessful. Skipping...===
# ===Record 1326: Dumaguete | <Status 200>===
# ===Record 1327: Seoul | <Status 200>===
# ===Record 1328: Ouesso | <Status 200>===
# ===Record 1329: Benjamin constant | <Status 200>===
# ===Record 1330: Vagay | <Status 200>===
# ===Record 1331: Cajabamba | <Status 200>===
# ===Record 1332: Shchigry | <Status 200>===
# ===Record 1333: Jupiter | <Status 200>===
# ===Record 1334: Kasongo-lunda | <Status 200>===
# ===Record 1335: Napier | <Status 200>===
# ===<Status: 404> | Request for city "Othonoi" was unsuccessful. Skipping...===
# ===Record 1336: Hwange | <Status 200>===
# ===Record 1337: Qui nhon | <Status 200>===
# ===<Status: 404> | Request for city "Kegayli" was unsuccessful. Skipping...===
# ===Record 1338: Kingaroy | <Status 200>===
# ===Record 1339: Orillia | <Status 200>===
# ===Record 1340: Tadepallegudem | <Status 200>===
# ===Record 1341: Snezhnogorsk | <Status 200>===
# ===Record 1342: Fort william | <Status 200>===
# ===Record 1343: Havre | <Status 200>===
# ===Record 1344: Salvador | <Status 200>===
# ===Record 1345: Champerico | <Status 200>===
# ===Record 1346: Misratah | <Status 200>===
# ===Record 1347: Egvekinot | <Status 200>===
# ===Record 1348: Cibitoke | <Status 200>===
# ===Record 1349: Mandalgovi | <Status 200>===
# ===Record 1350: Naryan-mar | <Status 200>===
# ===Record 1351: Huarmey | <Status 200>===
# ===Record 1352: Jamestown | <Status 200>===
# ===Record 1353: Aasiaat | <Status 200>===
# ===Record 1354: Udayagiri | <Status 200>===
# ===Record 1355: Gubkinskiy | <Status 200>===
# ===Record 1356: Maragogi | <Status 200>===
# ===Record 1357: Erenhot | <Status 200>===
# ===Record 1358: Belaya gora | <Status 200>===
# ===Record 1359: Srivardhan | <Status 200>===
# ===Record 1360: Glens falls | <Status 200>===
# ===Record 1361: Sarlat-la-caneda | <Status 200>===
# ===Record 1362: Blagoyevo | <Status 200>===
# ===Record 1363: Lyubim | <Status 200>===
# ===Record 1364: Bulaevo | <Status 200>===
# ===<Status: 404> | Request for city "Bokspits" was unsuccessful. Skipping...===
# ===Record 1365: Ulaangom | <Status 200>===
# ===Record 1366: Kodiak | <Status 200>===
# ===Record 1367: Xinmin | <Status 200>===
# ===Record 1368: Llangefni | <Status 200>===
# ===Record 1369: Yumen | <Status 200>===
# ===Record 1370: Waingapu | <Status 200>===
# ===Record 1371: Bhawana | <Status 200>===
# ===Record 1372: Port hedland | <Status 200>===
# ===<Status: 404> | Request for city "Labutta" was unsuccessful. Skipping...===
# ===Record 1373: Regeneracao | <Status 200>===
# ===Record 1374: Katsuura | <Status 200>===
# ===Record 1375: Sandwich | <Status 200>===
# ===Record 1376: Eydhafushi | <Status 200>===
# ===Record 1377: Morehead | <Status 200>===
# ===Record 1378: Kandrian | <Status 200>===
# ===Record 1379: Evanston | <Status 200>===
# ===Record 1380: Okhotsk | <Status 200>===
# ===Record 1381: Sao filipe | <Status 200>===
# ===Record 1382: Novobelokatay | <Status 200>===
# *******************************
# Incredibly Long List Finally Complete
# *******************************
# Data exported to csv file.

# %% [markdown]
# # Function Graveyard
# ### In my attempt to minimize the number of city requests that responded with a 404, I decided to write an analog to citipy's 'nearest_city' function using OpenWeatherMap's own list of cities.
# ### Their list, a ~40 mB .json file with over 4 million entries (citipy's list has around 47,000), proved messy in content and difficult for my computer to process.
# ### There were thousands of cities with the same name and country, just with slightly shifted coordinates, likely to give felxibility in searching by coordinate.
# ### After an attempt to clean, the set still had around a million cities.
# ### I made several attempts at a work-around (converting the .json to a DataFrame, then a .csv, taking the .json in chunks, streaming the .json, using different .json-serialization libraries, attempting to write asynchronously, avoiding list appends and loops as much as possible, etc...) but none of my code was fast enough to bare generating 100 cities, let alone over 1000 cities. This was depsite my code being almost identical to the inner workings of citipy's function.
# ### So, I swallowed my pride and returned to using citipy, which of course, turned out to work fine, with only about 100  cities returning a 404 status code when requested.

# %%
# # #finds the nearest city to any coordinate using OpenWeather's city list
# def coordcity(n):
#     return {t: NC(*t).city_name for t in random_coords(n)}

# def haversine(lat0,lng0,lat1,lng1):
#     latr0, latr1, lngr0, lngr1 = radians(lat0), radians(lat1), radians(lng0), radians(lng1)
#     dlat, dlng = (latr1-latr0), (lngr1-lngr0)
#     a = sin(dlat/2)**2 + cos(latr0)*cos(latr1)*sin(dlng/2)**2
#     c = 2 * atan2(sqrt(a), sqrt(1-a))
#     d = 6371 * c
#     return d

# def latlngfilter(lat,lng,n):
#     cities = [*data().index.values]
#     latlow, lathigh = lat - n, lat + n
#     lnglow, lnghigh = lng - n, lng + n
#     lam = lambda x: x[0] >= latlow and x[0] <= lathigh and x[1] >= lnglow and x[1] <= lnghigh
#     filtered = filter(lam,cities)
#     return filtered
    
# def bign(lat,lng):
#     n = 5
#     fil = lambda x: [*latlngfilter(lat,lng,x)]
#     while len(fil(n)) < 1:
#         n += 5
#     return n + 1

# def plantree(lat,lng):
#     n = bign(lat,lng)    
#     coordtree = spatial.cKDTree([x for x in latlngfilter(lat,lng,n)])
#     return coordtree

# def nc(lat,lng):
#     tree = plantree(lat,lng)
#     n = bign(lat,lng)
#     tree_query = tree.query_ball_point((lat,lng),n)
#     while len(tree_query) == 0:
#         n = n + 10
#         if n == 1000 and len(tree_query) == 0:
#             print('No city found | Default: Chicago')
#             return 'chicago'
#     havpairs = [(x,haversine(lat,lng,*x)) for x in tree.data[tree_query]]
#     if len(havpairs) == 0:
#         print('No city found | Default: Chicago')
#         return 'chicago'

# # Identify nearest city for each lat, lng combination
# def populatecities(n):
#     cities = []
#     while len(cities) < n:
#         noeditcities = [nc(x[0],x[1]) for x in random_coords(n)]
#         cities = list(set(noeditcities)) 
#     return cities

#     havmin = min(havpairs,key=lambda y: y[1])
#     return OWcities()[tuple(havmin[0])]

# # Identify nearest city for each lat, lng combination
# def populatecities2(n):
#     counter = 0
#     citydict = {}
#     allcities = []
#     while len(allcities) < n:
#         coords = [*random_coords(n)]
#         cities = (nc(x[0],x[1]) for x in coords if nc(x)!='antarctica')
#         citydict.update({counter: list(set(cities))})
#         counter += 1
#         allcities = [y for x in citydict.values() for y in x]
#         allcities = list(set(allcities))
#     return allcities

# %% [markdown]
# # Let's move on to the analysis!

# %%
def csvtoDF():
    weatherdf = pd.read_csv('outputs/worldweather.csv')
    return weatherdf

def latitudes():
    df = csvtoDF
    lats = [*df()['Latitude'].values]
    return lats

def northern():
    df = csvtoDF
    north = df()[df()['Latitude'] >= 0]
    return north

def southern():
    df = csvtoDF
    south = df()[df()['Latitude'] < 0]
    return south

def initialplots(linreg=False):
    north = northern
    south = southern
    xaxis = ['Max Temperature (F)','Humidity','Cloudiness', 'Wind Speed']
    for x in xaxis:
        yn = [*north()['Latitude'].values]
        xn = [*north()[x].values]
        ys = [*south()['Latitude'].values]
        xs = [*south()[x].values]
        if linreg != False:
            for z in [(xn,yn,'Northern','cool_r'),(xs,ys,'Southern','cool')]:
                fig, ax = plt.subplots(1,1,figsize=(10,10))
                m, b, r2, p, err = linregress(z[0],z[1])
                merr = linregress(z[0],z[1]).stderr
                berr = linregress(z[0],z[1]).intercept_stderr               
                ax.scatter(z[0],z[1],c=z[1],cmap=z[3])
                xlims = ax.get_xlim()
                xvals = np.linspace(xlims[0],xlims[1],1500)
                yvals = [m*n + b for n in xvals]
                ax.plot(xvals,yvals,color='k',label=f'r2 = {round(r2,4)}')
                ax.set_xlabel(x)
                ax.set_ylabel('Latitude')
                ax.set_title(f'{x} vs. {z[2]} Latitudes with Regression')
                ax.legend()
                regpath = f'outputs/{x}vs{z[2]}LatitudeRegression.png'
                plt.savefig(regpath)
                plt.close('all')
                print(f'***** Regression Results for {x} in the {z[2]} Hemisphere *****')
                print(f"In the {z[2]} hemisphere, on average, a city's {x} (x) and its latitude (L) have relation [L = {round(m,2)}*x + {round(b,2)}].")
                print(f"This relationship fits the data with a coefficient of determination of {round(r2,4)} and the regression has a p-value of {p}. The estimates for slope and intercept have error {round(merr,4)} and {round(berr,4)}, respectively.")
        else:
            fig, ax = plt.subplots(1,1,figsize=(10,10))
            ax.scatter(xn,yn,c=yn,cmap='cool_r')
            ax.scatter(xs,ys,c=ys,cmap='cool')
            ax.set_xlabel(x)
            ax.set_ylabel('Latitude')
            ax.set_title(f'{x} vs. Latitude')
            path = f'outputs/{x}vsLatitude.png'
            plt.savefig(path)
            plt.close('all')

# %%
initialplots(linreg=False)

# %% [markdown]
# # Initial Response
#
# ## From the look of these plots, the only weather attribute that is strongly related to Latitude is Max Temperature. As intuition would suggest, the maximum temperature increases as you get closer to the equator.
#
# ## The three other plots don't seem to show any correlation whatsoever between Latitude and the respecitve weather attribute.

# %%
initialplots(linreg=True)
# Out:
# ***** Regression Results for Max Temperature (F) in the Northern Hemisphere *****
# In the Northern hemisphere, on average, a city's Max Temperature (F) (x) and its latitude (L) have relation [L = -0.78*x + 85.81].
# This relationship fits the data with a coefficient of determination of -0.8129 and the regression has a p-value of 1.2325007937636762e-235. The estimates for slope and intercept have error 0.0177 and 1.1724, respectively.
# ***** Regression Results for Max Temperature (F) in the Southern Hemisphere *****
# In the Southern hemisphere, on average, a city's Max Temperature (F) (x) and its latitude (L) have relation [L = 0.72*x + -70.91].
# This relationship fits the data with a coefficient of determination of 0.723 and the regression has a p-value of 1.1591465211477142e-63. The estimates for slope and intercept have error 0.0351 and 2.5854, respectively.
# ***** Regression Results for Humidity in the Northern Hemisphere *****
# In the Northern hemisphere, on average, a city's Humidity (x) and its latitude (L) have relation [L = 0.11*x + 29.23].
# This relationship fits the data with a coefficient of determination of 0.1159 and the regression has a p-value of 0.0002477784830174639. The estimates for slope and intercept have error 0.0288 and 2.1076, respectively.
# ***** Regression Results for Humidity in the Southern Hemisphere *****
# In the Southern hemisphere, on average, a city's Humidity (x) and its latitude (L) have relation [L = -0.03*x + -16.64].
# This relationship fits the data with a coefficient of determination of -0.0552 and the regression has a p-value of 0.2796133673464018. The estimates for slope and intercept have error 0.0292 and 2.0137, respectively.
# ***** Regression Results for Cloudiness in the Northern Hemisphere *****
# In the Northern hemisphere, on average, a city's Cloudiness (x) and its latitude (L) have relation [L = 0.0*x + 36.45].
# This relationship fits the data with a coefficient of determination of 0.0071 and the regression has a p-value of 0.821859990390369. The estimates for slope and intercept have error 0.016 and 1.0743, respectively.
# ***** Regression Results for Cloudiness in the Southern Hemisphere *****
# In the Southern hemisphere, on average, a city's Cloudiness (x) and its latitude (L) have relation [L = 0.06*x + -22.18].
# This relationship fits the data with a coefficient of determination of 0.1712 and the regression has a p-value of 0.0007332725066365285. The estimates for slope and intercept have error 0.0189 and 1.2067, respectively.
# ***** Regression Results for Wind Speed in the Northern Hemisphere *****
# In the Northern hemisphere, on average, a city's Wind Speed (x) and its latitude (L) have relation [L = 0.58*x + 32.36].
# This relationship fits the data with a coefficient of determination of 0.1612 and the regression has a p-value of 3.172603098635387e-07. The estimates for slope and intercept have error 0.1126 and 1.0282, respectively.
# ***** Regression Results for Wind Speed in the Southern Hemisphere *****
# In the Southern hemisphere, on average, a city's Wind Speed (x) and its latitude (L) have relation [L = -0.1*x + -17.96].
# This relationship fits the data with a coefficient of determination of -0.0381 and the regression has a p-value of 0.4550034996313421. The estimates for slope and intercept have error 0.129 and 1.1851, respectively.

# %% [markdown]
# # Regression Analysis
#
# ## Like I said above, temperature and latitude certainly have a linear relationship, with temperature increasing as you get closer to the equator. The linear regressions have both relatively high absolute coefficients of determination and almost-zero p-values.
#
# ## Every other regression shows small coefficients of determination and larger p-values, meaning we can essentially reject the hypotheisis that the estimated line fits the data better than a line with slope zero.
